# %% [markdown]
# # 인천공항 이용자수 분석 및 예측
# 1. https://kosis.kr/search/search.do 접속.
# 2. 출입국 항구/내외국인/성별 국제이동(연간)검색.
# 3. 항목(우측사이드): 입국자,출국자,인천공항,내외국인,남여,기간 선택.
# 4. 피봇테이블설정.</br>
# ![image.png](attachment:1742a36d-5144-47ec-ba6c-841316b56676.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 1. 다운로드해 둔 나눔고딕 폰트 파일을 Matplotlib 엔진에 등록
font_path = "./NanumGothic-Regular.ttf"
fm.fontManager.addfont(font_path)

# 2. 폰트 설정 적용
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# 3. 테스트 텍스트 출력
plt.figure(figsize=(6, 4))
plt.text(0.2, 0.4, '한글', size=100)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic')
plt.text(0.2,0.4, '한글', size=100)
# Out:
# Text(0.2, 0.4, '한글')

# %%
file_path = "dataset/인천공항이용자수20260605.csv"
raw = pd.read_csv(file_path, encoding="EUC-KR") # UTF8
raw.sample(5)
# Out:
#     출입국항별 내외국인별    시점  성별   항목     데이터
# 73   인천공항   내국인  2019  남자  출국자  119872
# 1    인천공항   내국인  2001  남자  출국자   96551
# 32   인천공항   내국인  2009  남자  입국자  156396
# 162  인천공항   외국인  2017  여자  입국자  174969
# 155  인천공항   외국인  2015  여자  출국자  109977

# %%
# 컬럼명 바꾸기
ex1_data = raw.copy()
# 방법1
# ex1_data.columns = ['airport','type1','year','gender','type2','value']
# 방법2
ex1_data.rename(columns={
    '출입국항별':'airport',
    '내외국인별':'type1',
    '시점':'year',
    '성별':'gender',
    '항목':'type2',
    '데이터':'value'} , inplace=True )
ex1_data.columns
# Out:
# Index(['airport', 'type1', 'year', 'gender', 'type2', 'value'], dtype='str')

# %%
# 필터제작
filter1 = ex1_data['type1']=='외국인'
ex2_data = ex1_data[filter1].copy()
ex2_data.head()
# Out:
#     airport type1  year gender type2  value
# 96     인천공항   외국인  2001     남자   입국자  60699
# 97     인천공항   외국인  2001     남자   출국자  44548
# 98     인천공항   외국인  2001     여자   입국자  47963
# 99     인천공항   외국인  2001     여자   출국자  28348
# 100    인천공항   외국인  2002     남자   입국자  77745

# %%
# 년도별 통계
ex1_total = ex1_data.groupby('year')['value'].sum().reset_index(name='total')
ex1_total #.plot()
# plt.show()
# Out:
#     year    total
# 0   2001   521210
# 1   2002   697631
# 2   2003   747272
# 3   2004   769912
# 4   2005   991717
# 5   2006   996275
# 6   2007  1012415
# 7   2008  1080247
# 8   2009  1009778
# 9   2010  1019086
# 10  2011  1042475
# 11  2012  3133603
# 12  2013  1102487
# 13  2014  1118782
# 14  2015  1092457
# 15  2016  1120463
# 16  2017  1171045
# 17  2018  1227720
# 18  2019  1198598
# 19  2020  1129092
# 20  2021   867277
# 21  2022  1073387
# 22  2023  1124211
# 23  2024  1136691

# %%
filter2_in = ex2_data['type2']=='입국자'
ex2_in =  ex2_data[filter2_in]
filter2_out = ex2_data['type2']=='출국자'
ex2_out =  ex2_data[filter2_out]
ex2_in = ex2_in.groupby('year')['value'].sum().reset_index(name="intotal")
ex2_out = ex2_out.groupby('year')['value'].sum().reset_index(name="outtotal")

# %%
ex2_in.plot(figsize=(13,7),title="2015 ~ 2024년 인천공항 입국 외국인 차트")
# Out:
# <Axes: title={'center': '2015 ~ 2024년 인천공항 입국 외국인 차트'}>

# %%
ex2_out.plot(figsize=(13,7),title="2015 ~ 2024년 인천공항 출국 외국인 차트")
# Out:
# <Axes: title={'center': '2015 ~ 2024년 인천공항 출국 외국인 차트'}>

# %%
# ex2_in , ex2_out
plt.figure(figsize=(13,7))
plt.plot(ex2_in['year'],ex2_in['intotal'])
plt.plot(ex2_out['year'],ex2_out['outtotal'])
plt.title("2001 ~ 2024년 인천공항 입출국 외국인 차트")
plt.xlabel("기간")
plt.ylabel("입출국 외국인 수")
plt.savefig("./인천공항입출국차트.png")
plt.show()

# %%
#!pip install prophet
#!pip install plotly

# %%
from prophet import Prophet # time 은 ds, value 는 y 전처리필요

# %%
pro_data = ex2_in.copy()
pro_data['year'] = pd.to_datetime(pro_data['year'], format="%Y")
pro_data.rename(columns={'year':'ds','intotal':'y'}, inplace=True )
pro_data.head()
# Out:
#           ds       y
# 0 2001-01-01  108662
# 1 2002-01-01  135099
# 2 2003-01-01  140375
# 3 2004-01-01  149826
# 4 2005-01-01  214051

# %%
m = Prophet()
m.fit(pro_data)
# Out:
# 06:31:18 - cmdstanpy - INFO - Chain [1] start processing
# 06:31:18 - cmdstanpy - INFO - Chain [1] done processing

# %%
# 1. 미래 10년 데이터프레임 만들기 (freq='Y'는 연단위, periods=10은 10개년) / freq='Y' 에서 'YE'로 수정 (최신 Pandas 문법 반영)
future = m.make_future_dataframe(periods=10, freq='YE')

# 2. 미래 데이터 예측하기
forecast = m.predict(future)

# 3. 예측 결과 시각화 (한글 폰트가 깨지지 않도록 아까 설정해둔 상태여야 합니다)
fig1 = m.plot(forecast)

# 차트 제목 및 저장 설정
import matplotlib.pyplot as plt
plt.title("인천공항 입출국자수 10년 미래 예측", fontsize=16)
plt.savefig("./인천공항입출국차트(10년예측).png")
plt.show()

# 4. 예측된 데이터 수치 요약 보기 (ds: 날짜, yhat: 예측값, yhat_lower: 최저 예측치, yhat_upper: 최고 예측치)
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(10))
# Out:
#            ds           yhat     yhat_lower     yhat_upper
# 24 2024-12-31  477534.837465  327865.203030  629033.573962
# 25 2025-12-31  511160.924466  369252.051242  639903.426677
# 26 2026-12-31  544776.562862  408772.394424  688164.583228
# 27 2027-12-31  578352.713107  430851.865734  718931.347216
# 28 2028-12-31  516558.006459  371945.666978  655115.634479
# 29 2029-12-31  550184.093460  401258.808405  686639.380075
# 30 2030-12-31  583799.731856  449788.981119  733141.907632
# 31 2031-12-31  617375.882102  469782.000846  753636.685369
# 32 2032-12-31  555581.175453  416802.627692  692674.798604
# 33 2033-12-31  589207.262454  450646.826937  735450.087492

# %%
future = m.make_future_dataframe(periods=10, freq='YE')
forecast = m.predict(future)
fig1 = m.plot(forecast)
plt.savefig("./인천공항입출국차트(10년예측).png")
plt.show()

# %%
fig , ax = plt.subplots(2,2,figsize=(12,8))
ax[0,0].plot(ex2_in['year'],ex2_in['intotal'])
ax[0,1].plot(ex2_out['year'],ex2_out['outtotal'], color='orange')
ax[1,0].plot(ex2_in['year'],ex2_in['intotal'])
ax[1,0].plot(ex2_out['year'],ex2_out['outtotal'])
m.plot(forecast, ax=ax[1,1])

fig.suptitle('인천공항 입출국 통계', fontsize=16)
ax[0,0].set_title("2001년~2024년 인천공항 입국 외국인 차트")
ax[0,1].set_title("2001년~2024년 인천공항 출국 외국인 차트")
ax[1,0].set_title("2001년~2024년 인천공항 입/출국 외국인 차트")
ax[1,1].set_title("인천공항 외국인 입출국 10년 예측")
plt.savefig('인천공항입출국통계total.png')
plt.show()
