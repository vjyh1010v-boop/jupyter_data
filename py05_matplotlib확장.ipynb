# %% [markdown]
# # 시각화 모듈 Seaborn

# %%
# !pip install --upgrade pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 13.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 14.0 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.1
#     Uninstalling pandas-2.1.1:
#       Successfully uninstalled pandas-2.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.11.3 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.4.6 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 2.4.6 which is incompatible.
# ...

# %%
import seaborn as sns
